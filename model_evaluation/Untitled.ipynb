# %%
import os
scene='Room'
output_dir = '/home/superorange5/Research/FedWCD/output/baseline_noRoom/'+scene+'/'
input_dir = '/home/superorange5/Research/FedWCD/output/baseline_noRoom/detection_results'
for file in os.listdir(input_dir):
    
    if scene in file:

        if not os.path.exists(output_dir):
            os.makedirs(output_dir)
        print("copy {} to {}".format(os.path.join(input_dir, file),os.path.join(output_dir, file)))
        #shutil.copy2(os.path.join(input_dir, file), os.path.join(output_dir, file))
# Out:
# copy /home/superorange5/Research/FedWCD/output/baseline_noRoom/detection_results/Room_2_ch6_00109.txt to /home/superorange5/Research/FedWCD/output/baseline_noRoom/Room/Room_2_ch6_00109.txt
# copy /home/superorange5/Research/FedWCD/output/baseline_noRoom/detection_results/Room_2_ch4_00178.txt to /home/superorange5/Research/FedWCD/output/baseline_noRoom/Room/Room_2_ch4_00178.txt
# copy /home/superorange5/Research/FedWCD/output/baseline_noRoom/detection_results/Room_1_ch6_00134.txt to /home/superorange5/Research/FedWCD/output/baseline_noRoom/Room/Room_1_ch6_00134.txt
# copy /home/superorange5/Research/FedWCD/output/baseline_noRoom/detection_results/Room_1_ch2_00133.txt to /home/superorange5/Research/FedWCD/output/baseline_noRoom/Room/Room_1_ch2_00133.txt
# copy /home/superorange5/Research/FedWCD/output/baseline_noRoom/detection_results/Room_1_ch2_00130.txt to /home/superorange5/Research/FedWCD/output/baseline_noRoom/Room/Room_1_ch2_00130.txt
# ...
