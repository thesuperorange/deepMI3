# %% [markdown]
# ## load data

# %%
import pickle
pkl_file = 'data/cache/KAIST_campus_gt_roidb.pkl'
imdb_classes =  ('__background__',  # always index 0
                          'person',
                          'people','cyclist'
                         )
with open(pkl_file, 'rb') as f:
    roidb = pickle.load(f)
#roidb = filter_roidb(roidb)
len(roidb)
#ratio_list, ratio_index = rank_roidb_ratio(roidb)


#dataset = roibatchLoader(roidb, ratio_list, ratio_index, args.batch_size, imdb.num_classes, training=True)
# Out:
# 17276

# %%
roidb
# Out:
# [{'boxes': array([[329, 196, 368, 277]], dtype=uint16),
#   'gt_classes': array([1], dtype=int32),
#   'gt_ishard': array([0], dtype=int32),
#   'gt_overlaps': <1x4 sparse matrix of type '<class 'numpy.float32'>'
#   	with 1 stored elements in Compressed Sparse Row format>,
#   'flipped': False,
#   'seg_areas': array([3280.], dtype=float32),
#   'img_id': 10,
#   'image': '/home/superorange5/Research/2019_deepMI3/deepMI3/faster-RCNN/data/KAIST/JPEGImages/set03_V000_I03217.jpg',
#   'width': 640,
#   'height': 512,
#   'max_classes': array([1]),
#   'max_overlaps': array([1.], dtype=float32)},
#  {'boxes': array([[458, 237, 497, 318],
#          [548, 223, 576, 284]], dtype=uint16),
#   'gt_classes': array([1, 1], dtype=int32),
#   'gt_ishard': array([0, 0], dtype=int32),
#   'gt_overlaps': <2x4 sparse matrix of type '<class 'numpy.float32'>'
#   	with 2 stored elements in Compressed Sparse Row format>,
#   'flipped': False,
#   'seg_areas': array([3280., 1798.], dtype=float32),
#   'img_id': 11,
#   'image': '/home/superorange5/Research/2019_deepMI3/deepMI3/faster-RCNN/data/KAIST/JPEGImages/set00_V000_I02187.jpg',
#   'width': 640,
#   'height': 512,
#   'max_classes': array([1, 1]),
#   'max_overlaps': array([1., 1.], dtype=float32)},
#  {'boxes': array([[123, 209, 149, 253]], dtype=uint16),
#   'gt_classes': array([1], dtype=int32),
#   'gt_ishard': array([0], dtype=int32),
#   'gt_overlaps': <1x4 sparse matrix of type '<class 'numpy.float32'>'
#   	with 1 stored elements in Compressed Sparse Row format>,
#   'flipped': False,
#   'seg_areas': array([1215.], dtype=float32),
#   'img_id': 20,
#   'image': '/home/superorange5/Research/2019_deepMI3/deepMI3/faster-RCNN/data/KAIST/JPEGImages/set00_V001_I01062.jpg',
#   'width': 640,
#   'height': 512,
#   'max_classes': array([1]),
#   'max_overlaps': array([1.], dtype=float32)},
#  {'boxes': array([[559, 247, 616, 387],
#          [577, 233, 623, 375]], dtype=uint16),
#   'gt_classes': array([1, 1], dtype=int32),
#   'gt_ishard': array([0, 0], dtype=int32),
#   'gt_overlaps': <2x4 sparse matrix of type '<class 'numpy.float32'>'
#   	with 2 stored elements in Compressed Sparse Row format>,
#   'flipped': False,
#   'seg_areas': array([8178., 6721.], dtype=float32),
#   'img_id': 22,
#   'image': '/home/superorange5/Research/2019_deepMI3/deepMI3/faster-RCNN/data/KAIST/JPEGImages/set03_V001_I00653.jpg',
#   'width': 640,
#   'height': 512,
#   'max_classes': array([1, 1]),
#   'max_overlaps': array([1., 1.], dtype=float32)},
#  {'boxes': array([[384, 217, 419, 299]], dtype=uint16),
#   'gt_classes': array([1], dtype=int32),
#   'gt_ishard': array([0], dtype=int32),
#   'gt_overlaps': <1x4 sparse matrix of type '<class 'numpy.float32'>'
#   	with 1 stored elements in Compressed Sparse Row format>,
#   'flipped': False,
#   'seg_areas': array([2988.], dtype=float32),
#   'img_id': 28,
#   'image': '/home/superorange5/Research/2019_deepMI3/deepMI3/faster-RCNN/data/KAIST/JPEGImages/set03_V000_I01139.jpg',
#   'width': 640,
#   'height': 512,
#   'max_classes': array([1]),
#   'max_overlaps': array([1.], dtype=float32)},
#  {'boxes': array([[194, 189, 214, 218]], dtype=uint16),
#   'gt_classes': array([1], dtype=int32),
#   'gt_ishard': array([0], dtype=int32),
#   'gt_overlaps': <1x4 sparse matrix of type '<class 'numpy.float32'>'
#   	with 1 stored elements in Compressed Sparse Row format>,
#   'flipped': False,
#   'seg_areas': array([630.], dtype=float32),
#   'img_id': 29,
#   'image': '/home/superorange5/Research/2019_deepMI3/deepMI3/faster-RCNN/data/KAIST/JPEGImages/set00_V007_I01540.jpg',
#   'width': 640,
#   'height': 512,
#   'max_classes': array([1]),
#   'max_overlaps': array([1.], dtype=float32)},
#  {'boxes': array([[356, 215, 381, 281],
#          [306, 212, 328, 266],
#          [321, 217, 345, 262],
#          [335, 211, 365, 272]], dtype=uint16),
#   'gt_classes': array([1, 1, 1, 1], dtype=int32),
#   'gt_ishard': array([0, 0, 0, 0], dtype=int32),
#   'gt_overlaps': <4x4 sparse matrix of type '<class 'numpy.float32'>'
#   	with 4 stored elements in Compressed Sparse Row format>,
#   'flipped': False,
#   'seg_areas': array([1742., 1265., 1150., 1922.], dtype=float32),
#   'img_id': 31,
#   'image': '/home/superorange5/Research/2019_deepMI3/deepMI3/faster-RCNN/data/KAIST/JPEGImages/set03_V001_I00510.jpg',
#   'width': 640,
#   'height': 512,
#   'max_classes': array([1, 1, 1, 1]),
#   'max_overlaps': array([1., 1., 1., 1.], dtype=float32)},
#  {'boxes': array([[125, 214, 153, 266]], dtype=uint16),
#   'gt_classes': array([3], dtype=int32),
#   'gt_ishard': array([0], dtype=int32),
#   'gt_overlaps': <1x4 sparse matrix of type '<class 'numpy.float32'>'
#   	with 1 stored elements in Compressed Sparse Row format>,
#   'flipped': False,
#   'seg_areas': array([1537.], dtype=float32),
#   'img_id': 36,
#   'image': '/home/superorange5/Research/2019_deepMI3/deepMI3/faster-RCNN/data/KAIST/JPEGImages/set00_V000_I01105.jpg',
#   'width': 640,
#   'height': 512,
#   'max_classes': array([3]),
#   'max_overlaps': array([1.], dtype=float32)},
#  {'boxes': array([[167, 212, 191, 260]], dtype=uint16),
#   'gt_classes': array([3], dtype=int32),
#   'gt_ishard': array([0], dtype=int32),
#   'gt_overlaps': <1x4 sparse matrix of type '<class 'numpy.float32'>'
#   	with 1 stored elements in Compressed Sparse Row format>,
#   'flipped': False,
#   'seg_areas': array([1225.], dtype=float32),
#   'img_id': 37,
#   'image': '/home/superorange5/Research/2019_deepMI3/deepMI3/faster-RCNN/data/KAIST/JPEGImages/set03_V001_I01323.jpg',
#   'width': 640,
#   'height': 512,
#   'max_classes': array([3]),
#   'max_overlaps': array([1.], dtype=float32)},
#  {'boxes': array([[ 98, 214, 138, 297]], dtype=uint16),
#   'gt_classes': array([3], dtype=int32),
#   'gt_ishard': array([0], dtype=int32),
#   'gt_overlaps': <1x4 sparse matrix of type '<class 'numpy.float32'>'
#   	with 1 stored elements in Compressed Sparse Row format>,
#   'flipped': False,
#   'seg_areas': array([3444.], dtype=float32),
#   'img_id': 39,
#   'image': '/home/superorange5/Research/2019_deepMI3/deepMI3/faster-RCNN/data/KAIST/JPEGImages/set00_V004_I01517.jpg',
#   'width': 640,
#   'height': 512,
#   'max_classes': array([3]),
#   'max_overlaps': array([1.], dtype=float32)},
#  {'boxes': array([[165, 210, 186, 260],
#          [184, 210, 208, 261]], dtype=uint16),
#   'gt_classes': array([1, 1], dtype=int32),
#   'gt_ishard': array([0, 0], dtype=int32),
#   'gt_overlaps': <2x4 sparse matrix of type '<class 'numpy.float32'>'
#   	with 2 stored elements in Compressed Sparse Row format>,
#   'flipped': False,
#   'seg_areas': array([1122., 1300.], dtype=float32),
#   'img_id': 42,
#   'image': '/home/superorange5/Research/2019_deepMI3/deepMI3/faster-RCNN/data/KAIST/JPEGImages/set00_V000_I01225.jpg',
#   'width': 640,
#   'height': 512,
#   'max_classes': array([1, 1]),
#   'max_overlaps': array([1., 1.], dtype=float32)},
#  {'boxes': array([[383, 219, 420, 295]], dtype=uint16),
#   'gt_classes': array([1], dtype=int32),
#   'gt_ishard': array([0], dtype=int32),
#   'gt_overlaps': <1x4 sparse matrix of type '<class 'numpy.float32'>'
#   	with 1 stored elements in Compressed Sparse Row format>,
#   'flipped': False,
#   'seg_areas': array([2926.], dtype=float32),
#   'img_id': 44,
#   'image': '/home/superorange5/Research/2019_deepMI3/deepMI3/faster-RCNN/data/KAIST/JPEGImages/set00_V002_I00440.jpg',
#   'width': 640,
#   'height': 512,
#   'max_classes': array([1]),
#   'max_overlaps': array([1.], dtype=float32)},
#  {'boxes': array([[375, 225, 396, 266],
#          [256, 221, 276, 267]], dtype=uint16),
#   'gt_classes': array([3, 3], dtype=int32),
#   'gt_ishard': array([0, 0], dtype=int32),
#   'gt_overlaps': <2x4 sparse matrix of type '<class 'numpy.float32'>'
#   	with 2 stored elements in Compressed Sparse Row format>,
#   'flipped': False,
#   'seg_areas': array([924., 987.], dtype=float32),
#   'img_id': 49,
#   'image': '/home/superorange5/Research/2019_deepMI3/deepMI3/faster-RCNN/data/KAIST/JPEGImages/set00_V005_I00757.jpg',
#   'width': 640,
#   'height': 512,
#   'max_classes': array([3, 3]),
#   'max_overlaps': array([1., 1.], dtype=float32)},
#  {'boxes': array([[334, 212, 354, 241]], dtype=uint16),
#   'gt_classes': array([2], dtype=int32),
#   'gt_ishard': array([0], dtype=int32),
#   'gt_overlaps': <1x4 sparse matrix of type '<class 'numpy.float32'>'
#   	with 1 stored elements in Compressed Sparse Row format>,
#   'flipped': False,
#   'seg_areas': array([630.], dtype=float32),
#   'img_id': 50,
#   'image': '/home/superorange5/Research/2019_deepMI3/deepMI3/faster-RCNN/data/KAIST/JPEGImages/set00_V003_I00499.jpg',
#   'width': 640,
#   'height': 512,
#   'max_classes': array([2]),
#   'max_overlaps': array([1.], dtype=float32)},
#  {'boxes': array([[ 75, 214, 108, 291],
#          [172, 223, 204, 288]], dtype=uint16),
#   'gt_classes': array([1, 1], dtype=int32),
#   'gt_ishard': array([0, 0], dtype=int32),
#   'gt_overlaps': <2x4 sparse matrix of type '<class 'numpy.float32'>'
#   	with 2 stored elements in Compressed Sparse Row format>,
#   'flipped': False,
#   'seg_areas': array([2652., 2178.], dtype=float32),
#   'img_id': 60,
#   'image': '/home/superorange5/Research/2019_deepMI3/deepMI3/faster-RCNN/data/KAIST/JPEGImages/set00_V000_I01667.jpg',
#   'width': 640,
#   'height': 512,
#   'max_classes': array([1, 1]),
#   'max_overlaps': array([1., 1.], dtype=float32)},
#  {'boxes': array([[352, 219, 372, 262]], dtype=uint16),
#   'gt_classes': array([1], dtype=int32),
#   'gt_ishard': array([0], dtype=int32),
#   'gt_overlaps': <1x4 sparse matrix of type '<class 'numpy.float32'>'
#   	with 1 stored elements in Compressed Sparse Row format>,
#   'flipped': False,
#   'seg_areas': array([924.], dtype=float32),
#   'img_id': 69,
#   'image': '/home/superorange5/Research/2019_deepMI3/deepMI3/faster-RCNN/data/KAIST/JPEGImages/set00_V004_I01661.jpg',
#   'width': 640,
#   'height': 512,
#   'max_classes': array([1]),
#   'max_overlaps': array([1.], dtype=float32)},
#  {'boxes': array([[194, 215, 229, 290]], dtype=uint16),
#   'gt_classes': array([1], dtype=int32),
#   'gt_ishard': array([0], dtype=int32),
#   'gt_overlaps': <1x4 sparse matrix of type '<class 'numpy.float32'>'
#   	with 1 stored elements in Compressed Sparse Row format>,
#   'flipped': False,
#   'seg_areas': array([2736.], dtype=float32),
#   'img_id': 72,
#   'image': '/home/superorange5/Research/2019_deepMI3/deepMI3/faster-RCNN/data/KAIST/JPEGImages/set03_V000_I01044.jpg',
#   'width': 640,
#   'height': 512,
#   'max_classes': array([1]),
#   'max_overlaps': array([1.], dtype=float32)},
#  {'boxes': array([[440, 231, 488, 364]], dtype=uint16),
#   'gt_classes': array([1], dtype=int32),
#   'gt_ishard': array([0], dtype=int32),
#   'gt_overlaps': <1x4 sparse matrix of type '<class 'numpy.float32'>'
#   	with 1 stored elements in Compressed Sparse Row format>,
#   'flipped': False,
#   'seg_areas': array([6566.], dtype=float32),
#   'img_id': 75,
#   'image': '/home/superorange5/Research/2019_deepMI3/deepMI3/faster-RCNN/data/KAIST/JPEGImages/set00_V006_I00304.jpg',
#   'width': 640,
#   'height': 512,
#   'max_classes': array([1]),
#   'max_overlaps': array([1.], dtype=float32)},
#  {'boxes': array([[545, 234, 607, 377],
#          [569, 214, 617, 354]], dtype=uint16),
#   'gt_classes': array([1, 1], dtype=int32),
#   'gt_ishard': array([0, 0], dtype=int32),
#   'gt_overlaps': <2x4 sparse matrix of type '<class 'numpy.float32'>'
#   	with 2 stored elements in Compressed Sparse Row format>,
#   'flipped': False,
#   'seg_areas': array([9072., 6909.], dtype=float32),
#   'img_id': 76,
#   'image': '/home/superorange5/Research/2019_deepMI3/deepMI3/faster-RCNN/data/KAIST/JPEGImages/set03_V001_I00649.jpg',
#   'width': 640,
#   'height': 512,
#   'max_classes': array([1, 1]),
#   'max_overlaps': array([1., 1.], dtype=float32)},
#  {'boxes': array([[437, 214, 458, 262],
#          [423, 213, 444, 263]], dtype=uint16),
#   'gt_classes': array([1, 1], dtype=int32),
#   'gt_ishard': array([0, 0], dtype=int32),
#   'gt_overlaps': <2x4 sparse matrix of type '<class 'numpy.float32'>'
#   	with 2 stored elements in Compressed Sparse Row format>,
#   'flipped': False,
#   'seg_areas': array([1078., 1122.], dtype=float32),
#   'img_id': 78,
#   'image': '/home/superorange5/Research/2019_deepMI3/deepMI3/faster-RCNN/data/KAIST/JPEGImages/set00_V004_I00776.jpg',
#   'width': 640,
#   'height': 512,
#   'max_classes': array([1, 1]),
#   'max_overlaps': array([1., 1.], dtype=float32)},
#  {'boxes': array([[ 25, 225,  51, 285]], dtype=uint16),
#   'gt_classes': array([1], dtype=int32),
#   'gt_ishard': array([0], dtype=int32),
#   'gt_overlaps': <1x4 sparse matrix of type '<class 'numpy.float32'>'
#   	with 1 stored elements in Compressed Sparse Row format>,
#   'flipped': False,
#   'seg_areas': array([1647.], dtype=float32),
#   'img_id': 79,
#   'image': '/home/superorange5/Research/2019_deepMI3/deepMI3/faster-RCNN/data/KAIST/JPEGImages/set00_V001_I01973.jpg',
#   'width': 640,
#   'height': 512,
#   'max_classes': array([1]),
#   'max_overlaps': array([1.], dtype=float32)},
#  {'boxes': array([[441, 208, 463, 259],
#          [427, 210, 447, 259]], dtype=uint16),
#   'gt_classes': array([1, 1], dtype=int32),
#   'gt_ishard': array([0, 0], dtype=int32),
#   'gt_overlaps': <2x4 sparse matrix of type '<class 'numpy.float32'>'
#   	with 2 stored elements in Compressed Sparse Row format>,
#   'flipped': False,
#   'seg_areas': array([1196., 1050.], dtype=float32),
#   'img_id': 80,
#   'image': '/home/superorange5/Research/2019_deepMI3/deepMI3/faster-RCNN/data/KAIST/JPEGImages/set00_V004_I00779.jpg',
#   'width': 640,
#   'height': 512,
#   'max_classes': array([1, 1]),
#   'max_overlaps': array([1., 1.], dtype=float32)},
#  {'boxes': array([[114, 215, 140, 263]], dtype=uint16),
#   'gt_classes': array([1], dtype=int32),
#   'gt_ishard': array([0], dtype=int32),
#   'gt_overlaps': <1x4 sparse matrix of type '<class 'numpy.float32'>'
#   	with 1 stored elements in Compressed Sparse Row format>,
#   'flipped': False,
#   'seg_areas': array([1323.], dtype=float32),
#   'img_id': 81,
#   'image': '/home/superorange5/Research/2019_deepMI3/deepMI3/faster-RCNN/data/KAIST/JPEGImages/set00_V001_I02474.jpg',
#   'width': 640,
#   'height': 512,
#   'max_classes': array([1]),
#   'max_overlaps': array([1.], dtype=float32)},
#  {'boxes': array([[127, 225, 150, 281],
#          [103, 225, 126, 282]], dtype=uint16),
#   'gt_classes': array([1, 1], dtype=int32),
#   'gt_ishard': array([0, 0], dtype=int32),
#   'gt_overlaps': <2x4 sparse matrix of type '<class 'numpy.float32'>'
#   	with 2 stored elements in Compressed Sparse Row format>,
#   'flipped': False,
#   'seg_areas': array([1368., 1392.], dtype=float32),
#   'img_id': 82,
#   'image': '/home/superorange5/Research/2019_deepMI3/deepMI3/faster-RCNN/data/KAIST/JPEGImages/set00_V006_I00078.jpg',
#   'width': 640,
#   'height': 512,
#   'max_classes': array([1, 1]),
#   'max_overlaps': array([1., 1.], dtype=float32)},
#  {'boxes': array([[213, 224, 252, 316],
#          [339, 209, 364, 271],
#          [432, 213, 450, 258],
#          [445, 211, 465, 259],
#          [279, 216, 306, 286],
#          [249, 216, 277, 289]], dtype=uint16),
#   'gt_classes': array([1, 1, 1, 1, 1, 1], dtype=int32),
#   'gt_ishard': array([0, 0, 0, 0, 0, 0], dtype=int32),
#   'gt_overlaps': <6x4 sparse matrix of type '<class 'numpy.float32'>'
#   	with 6 stored elements in Compressed Sparse Row format>,
#   'flipped': False,
#   'seg_areas': array([3720., 1638.,  874., 1029., 1988., 2146.], dtype=float32),
#   'img_id': 83,
#   'image': '/home/superorange5/Research/2019_deepMI3/deepMI3/faster-RCNN/data/KAIST/JPEGImages/set00_V008_I00340.jpg',
#   'width': 640,
#   'height': 512,
#   'max_classes': array([1, 1, 1, 1, 1, 1]),
#   'max_overlaps': array([1., 1., 1., 1., 1., 1.], dtype=float32)},
#  {'boxes': array([[272, 196, 311, 277]], dtype=uint16),
#   'gt_overlaps': <1x4 sparse matrix of type '<class 'numpy.float32'>'
#   	with 1 stored elements in Compressed Sparse Row format>,
#   'gt_classes': array([1], dtype=int32),
#   'flipped': True,
#   'img_id': 95,
#   'image': '/home/superorange5/Research/2019_deepMI3/deepMI3/faster-RCNN/data/KAIST/JPEGImages/set03_V000_I03217.jpg',
#   'width': 640,
#   'height': 512,
#   'max_classes': array([1]),
#   'max_overlaps': array([1.], dtype=float32)},
#  {'boxes': array([[143, 237, 182, 318],
#          [ 64, 223,  92, 284]], dtype=uint16),
#   'gt_overlaps': <2x4 sparse matrix of type '<class 'numpy.float32'>'
#   	with 2 stored elements in Compressed Sparse Row format>,
#   'gt_classes': array([1, 1], dtype=int32),
#   'flipped': True,
#   'img_id': 96,
#   'image': '/home/superorange5/Research/2019_deepMI3/deepMI3/faster-RCNN/data/KAIST/JPEGImages/set00_V000_I02187.jpg',
#   'width': 640,
#   'height': 512,
#   'max_classes': array([1, 1]),
#   'max_overlaps': array([1., 1.], dtype=float32)},
#  {'boxes': array([[491, 209, 517, 253]], dtype=uint16),
#   'gt_overlaps': <1x4 sparse matrix of type '<class 'numpy.float32'>'
#   	with 1 stored elements in Compressed Sparse Row format>,
#   'gt_classes': array([1], dtype=int32),
#   'flipped': True,
#   'img_id': 105,
#   'image': '/home/superorange5/Research/2019_deepMI3/deepMI3/faster-RCNN/data/KAIST/JPEGImages/set00_V001_I01062.jpg',
#   'width': 640,
#   'height': 512,
#   'max_classes': array([1]),
#   'max_overlaps': array([1.], dtype=float32)},
#  {'boxes': array([[ 24, 247,  81, 387],
#          [ 17, 233,  63, 375]], dtype=uint16),
#   'gt_overlaps': <2x4 sparse matrix of type '<class 'numpy.float32'>'
#   	with 2 stored elements in Compressed Sparse Row format>,
#   'gt_classes': array([1, 1], dtype=int32),
#   'flipped': True,
#   'img_id': 107,
#   'image': '/home/superorange5/Research/2019_deepMI3/deepMI3/faster-RCNN/data/KAIST/JPEGImages/set03_V001_I00653.jpg',
#   'width': 640,
#   'height': 512,
#   'max_classes': array([1, 1]),
#   'max_overlaps': array([1., 1.], dtype=float32)},
#  {'boxes': array([[221, 217, 256, 299]], dtype=uint16),
#   'gt_overlaps': <1x4 sparse matrix of type '<class 'numpy.float32'>'
#   	with 1 stored elements in Compressed Sparse Row format>,
#   'gt_classes': array([1], dtype=int32),
#   'flipped': True,
#   'img_id': 113,
#   'image': '/home/superorange5/Research/2019_deepMI3/deepMI3/faster-RCNN/data/KAIST/JPEGImages/set03_V000_I01139.jpg',
#   'width': 640,
#   'height': 512,
#   'max_classes': array([1]),
#   'max_overlaps': array([1.], dtype=float32)},
#  {'boxes': array([[426, 189, 446, 218]], dtype=uint16),
#   'gt_overlaps': <1x4 sparse matrix of type '<class 'numpy.float32'>'
#   	with 1 stored elements in Compressed Sparse Row format>,
#   'gt_classes': array([1], dtype=int32),
#   'flipped': True,
#   'img_id': 114,
#   'image': '/home/superorange5/Research/2019_deepMI3/deepMI3/faster-RCNN/data/KAIST/JPEGImages/set00_V007_I01540.jpg',
#   'width': 640,
#   'height': 512,
#   'max_classes': array([1]),
#   'max_overlaps': array([1.], dtype=float32)},
#  {'boxes': array([[259, 215, 284, 281],
#          [312, 212, 334, 266],
#          [295, 217, 319, 262],
#          [275, 211, 305, 272]], dtype=uint16),
#   'gt_overlaps': <4x4 sparse matrix of type '<class 'numpy.float32'>'
#   	with 4 stored elements in Compressed Sparse Row format>,
#   'gt_classes': array([1, 1, 1, 1], dtype=int32),
#   'flipped': True,
#   'img_id': 116,
#   'image': '/home/superorange5/Research/2019_deepMI3/deepMI3/faster-RCNN/data/KAIST/JPEGImages/set03_V001_I00510.jpg',
#   'width': 640,
#   'height': 512,
#   'max_classes': array([1, 1, 1, 1]),
#   'max_overlaps': array([1., 1., 1., 1.], dtype=float32)},
#  {'boxes': array([[487, 214, 515, 266]], dtype=uint16),
#   'gt_overlaps': <1x4 sparse matrix of type '<class 'numpy.float32'>'
#   	with 1 stored elements in Compressed Sparse Row format>,
#   'gt_classes': array([3], dtype=int32),
#   'flipped': True,
#   'img_id': 121,
#   'image': '/home/superorange5/Research/2019_deepMI3/deepMI3/faster-RCNN/data/KAIST/JPEGImages/set00_V000_I01105.jpg',
#   'width': 640,
#   'height': 512,
#   'max_classes': array([3]),
#   'max_overlaps': array([1.], dtype=float32)},
#  {'boxes': array([[449, 212, 473, 260]], dtype=uint16),
#   'gt_overlaps': <1x4 sparse matrix of type '<class 'numpy.float32'>'
#   	with 1 stored elements in Compressed Sparse Row format>,
#   'gt_classes': array([3], dtype=int32),
#   'flipped': True,
#   'img_id': 122,
#   'image': '/home/superorange5/Research/2019_deepMI3/deepMI3/faster-RCNN/data/KAIST/JPEGImages/set03_V001_I01323.jpg',
#   'width': 640,
#   'height': 512,
#   'max_classes': array([3]),
#   'max_overlaps': array([1.], dtype=float32)},
#  {'boxes': array([[502, 214, 542, 297]], dtype=uint16),
#   'gt_overlaps': <1x4 sparse matrix of type '<class 'numpy.float32'>'
#   	with 1 stored elements in Compressed Sparse Row format>,
#   'gt_classes': array([3], dtype=int32),
#   'flipped': True,
#   'img_id': 124,
#   'image': '/home/superorange5/Research/2019_deepMI3/deepMI3/faster-RCNN/data/KAIST/JPEGImages/set00_V004_I01517.jpg',
#   'width': 640,
#   'height': 512,
#   'max_classes': array([3]),
#   'max_overlaps': array([1.], dtype=float32)},
#  {'boxes': array([[454, 210, 475, 260],
#          [432, 210, 456, 261]], dtype=uint16),
#   'gt_overlaps': <2x4 sparse matrix of type '<class 'numpy.float32'>'
#   	with 2 stored elements in Compressed Sparse Row format>,
#   'gt_classes': array([1, 1], dtype=int32),
#   'flipped': True,
#   'img_id': 127,
#   'image': '/home/superorange5/Research/2019_deepMI3/deepMI3/faster-RCNN/data/KAIST/JPEGImages/set00_V000_I01225.jpg',
#   'width': 640,
#   'height': 512,
#   'max_classes': array([1, 1]),
#   'max_overlaps': array([1., 1.], dtype=float32)},
#  {'boxes': array([[220, 219, 257, 295]], dtype=uint16),
#   'gt_overlaps': <1x4 sparse matrix of type '<class 'numpy.float32'>'
#   	with 1 stored elements in Compressed Sparse Row format>,
#   'gt_classes': array([1], dtype=int32),
#   'flipped': True,
#   'img_id': 129,
#   'image': '/home/superorange5/Research/2019_deepMI3/deepMI3/faster-RCNN/data/KAIST/JPEGImages/set00_V002_I00440.jpg',
#   'width': 640,
#   'height': 512,
#   'max_classes': array([1]),
#   'max_overlaps': array([1.], dtype=float32)},
#  {'boxes': array([[244, 225, 265, 266],
#          [364, 221, 384, 267]], dtype=uint16),
#   'gt_overlaps': <2x4 sparse matrix of type '<class 'numpy.float32'>'
#   	with 2 stored elements in Compressed Sparse Row format>,
#   'gt_classes': array([3, 3], dtype=int32),
#   'flipped': True,
#   'img_id': 134,
#   'image': '/home/superorange5/Research/2019_deepMI3/deepMI3/faster-RCNN/data/KAIST/JPEGImages/set00_V005_I00757.jpg',
#   'width': 640,
#   'height': 512,
#   'max_classes': array([3, 3]),
#   'max_overlaps': array([1., 1.], dtype=float32)},
#  {'boxes': array([[286, 212, 306, 241]], dtype=uint16),
#   'gt_overlaps': <1x4 sparse matrix of type '<class 'numpy.float32'>'
#   	with 1 stored elements in Compressed Sparse Row format>,
#   'gt_classes': array([2], dtype=int32),
#   'flipped': True,
#   'img_id': 135,
#   'image': '/home/superorange5/Research/2019_deepMI3/deepMI3/faster-RCNN/data/KAIST/JPEGImages/set00_V003_I00499.jpg',
#   'width': 640,
#   'height': 512,
#   'max_classes': array([2]),
#   'max_overlaps': array([1.], dtype=float32)},
#  {'boxes': array([[532, 214, 565, 291],
#          [436, 223, 468, 288]], dtype=uint16),
#   'gt_overlaps': <2x4 sparse matrix of type '<class 'numpy.float32'>'
#   	with 2 stored elements in Compressed Sparse Row format>,
#   'gt_classes': array([1, 1], dtype=int32),
#   'flipped': True,
#   'img_id': 145,
#   'image': '/home/superorange5/Research/2019_deepMI3/deepMI3/faster-RCNN/data/KAIST/JPEGImages/set00_V000_I01667.jpg',
#   'width': 640,
#   'height': 512,
#   'max_classes': array([1, 1]),
#   'max_overlaps': array([1., 1.], dtype=float32)},
#  {'boxes': array([[268, 219, 288, 262]], dtype=uint16),
#   'gt_overlaps': <1x4 sparse matrix of type '<class 'numpy.float32'>'
#   	with 1 stored elements in Compressed Sparse Row format>,
#   'gt_classes': array([1], dtype=int32),
#   'flipped': True,
#   'img_id': 154,
#   'image': '/home/superorange5/Research/2019_deepMI3/deepMI3/faster-RCNN/data/KAIST/JPEGImages/set00_V004_I01661.jpg',
#   'width': 640,
#   'height': 512,
#   'max_classes': array([1]),
#   'max_overlaps': array([1.], dtype=float32)},
#  {'boxes': array([[411, 215, 446, 290]], dtype=uint16),
#   'gt_overlaps': <1x4 sparse matrix of type '<class 'numpy.float32'>'
#   	with 1 stored elements in Compressed Sparse Row format>,
#   'gt_classes': array([1], dtype=int32),
#   'flipped': True,
#   'img_id': 157,
#   'image': '/home/superorange5/Research/2019_deepMI3/deepMI3/faster-RCNN/data/KAIST/JPEGImages/set03_V000_I01044.jpg',
#   'width': 640,
#   'height': 512,
#   'max_classes': array([1]),
#   'max_overlaps': array([1.], dtype=float32)},
#  {'boxes': array([[152, 231, 200, 364]], dtype=uint16),
#   'gt_overlaps': <1x4 sparse matrix of type '<class 'numpy.float32'>'
#   	with 1 stored elements in Compressed Sparse Row format>,
#   'gt_classes': array([1], dtype=int32),
#   'flipped': True,
#   'img_id': 160,
#   'image': '/home/superorange5/Research/2019_deepMI3/deepMI3/faster-RCNN/data/KAIST/JPEGImages/set00_V006_I00304.jpg',
#   'width': 640,
#   'height': 512,
#   'max_classes': array([1]),
#   'max_overlaps': array([1.], dtype=float32)},
#  {'boxes': array([[ 33, 234,  95, 377],
#          [ 23, 214,  71, 354]], dtype=uint16),
#   'gt_overlaps': <2x4 sparse matrix of type '<class 'numpy.float32'>'
#   	with 2 stored elements in Compressed Sparse Row format>,
#   'gt_classes': array([1, 1], dtype=int32),
#   'flipped': True,
#   'img_id': 161,
#   'image': '/home/superorange5/Research/2019_deepMI3/deepMI3/faster-RCNN/data/KAIST/JPEGImages/set03_V001_I00649.jpg',
#   'width': 640,
#   'height': 512,
#   'max_classes': array([1, 1]),
#   'max_overlaps': array([1., 1.], dtype=float32)},
#  {'boxes': array([[182, 214, 203, 262],
#          [196, 213, 217, 263]], dtype=uint16),
#   'gt_overlaps': <2x4 sparse matrix of type '<class 'numpy.float32'>'
#   	with 2 stored elements in Compressed Sparse Row format>,
#   'gt_classes': array([1, 1], dtype=int32),
#   'flipped': True,
#   'img_id': 163,
#   'image': '/home/superorange5/Research/2019_deepMI3/deepMI3/faster-RCNN/data/KAIST/JPEGImages/set00_V004_I00776.jpg',
#   'width': 640,
#   'height': 512,
#   'max_classes': array([1, 1]),
#   'max_overlaps': array([1., 1.], dtype=float32)},
#  {'boxes': array([[589, 225, 615, 285]], dtype=uint16),
#   'gt_overlaps': <1x4 sparse matrix of type '<class 'numpy.float32'>'
#   	with 1 stored elements in Compressed Sparse Row format>,
#   'gt_classes': array([1], dtype=int32),
#   'flipped': True,
#   'img_id': 164,
#   'image': '/home/superorange5/Research/2019_deepMI3/deepMI3/faster-RCNN/data/KAIST/JPEGImages/set00_V001_I01973.jpg',
#   'width': 640,
#   'height': 512,
#   'max_classes': array([1]),
#   'max_overlaps': array([1.], dtype=float32)},
#  {'boxes': array([[177, 208, 199, 259],
#          [193, 210, 213, 259]], dtype=uint16),
#   'gt_overlaps': <2x4 sparse matrix of type '<class 'numpy.float32'>'
#   	with 2 stored elements in Compressed Sparse Row format>,
#   'gt_classes': array([1, 1], dtype=int32),
#   'flipped': True,
#   'img_id': 165,
#   'image': '/home/superorange5/Research/2019_deepMI3/deepMI3/faster-RCNN/data/KAIST/JPEGImages/set00_V004_I00779.jpg',
#   'width': 640,
#   'height': 512,
#   'max_classes': array([1, 1]),
#   'max_overlaps': array([1., 1.], dtype=float32)},
#  {'boxes': array([[500, 215, 526, 263]], dtype=uint16),
#   'gt_overlaps': <1x4 sparse matrix of type '<class 'numpy.float32'>'
#   	with 1 stored elements in Compressed Sparse Row format>,
#   'gt_classes': array([1], dtype=int32),
#   'flipped': True,
#   'img_id': 166,
#   'image': '/home/superorange5/Research/2019_deepMI3/deepMI3/faster-RCNN/data/KAIST/JPEGImages/set00_V001_I02474.jpg',
#   'width': 640,
#   'height': 512,
#   'max_classes': array([1]),
#   'max_overlaps': array([1.], dtype=float32)},
#  {'boxes': array([[490, 225, 513, 281],
#          [514, 225, 537, 282]], dtype=uint16),
#   'gt_overlaps': <2x4 sparse matrix of type '<class 'numpy.float32'>'
#   	with 2 stored elements in Compressed Sparse Row format>,
#   'gt_classes': array([1, 1], dtype=int32),
#   'flipped': True,
#   'img_id': 167,
#   'image': '/home/superorange5/Research/2019_deepMI3/deepMI3/faster-RCNN/data/KAIST/JPEGImages/set00_V006_I00078.jpg',
#   'width': 640,
#   'height': 512,
#   'max_classes': array([1, 1]),
#   'max_overlaps': array([1., 1.], dtype=float32)},
#  {'boxes': array([[388, 224, 427, 316],
#          [276, 209, 301, 271],
#          [190, 213, 208, 258],
#          [175, 211, 195, 259],
#          [334, 216, 361, 286],
#          [363, 216, 391, 289]], dtype=uint16),
#   'gt_overlaps': <6x4 sparse matrix of type '<class 'numpy.float32'>'
#   	with 6 stored elements in Compressed Sparse Row format>,
#   'gt_classes': array([1, 1, 1, 1, 1, 1], dtype=int32),
#   'flipped': True,
#   'img_id': 168,
#   'image': '/home/superorange5/Research/2019_deepMI3/deepMI3/faster-RCNN/data/KAIST/JPEGImages/set00_V008_I00340.jpg',
#   'width': 640,
#   'height': 512,
#   'max_classes': array([1, 1, 1, 1, 1, 1]),
#   'max_overlaps': array([1., 1., 1., 1., 1., 1.], dtype=float32)}]
